# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop

# %%
def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
                     kernel_size=(3, 3),
                     activation='relu',
                     input_shape=in_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    return model

def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    return model

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a92cd60255ca> in <module>()
#       3 from sklearn.model_selection import train_test_split
#       4 from keras.utils import np_utils
# ----> 5 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
im_rows = 32
im_cols = 32
im_color =3
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255
y = keras.utils.np_utils.to_categorical(y.astype('int32'), nb_classes)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2, random_state=0)

x_new = []
y_new = []




model = get_model(in_shape, nb_classes)

hist = model.fit(x_train, y_train,
                batch_size=32,
                epochs=20,
                verbose=1,
                validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=1)
print('正解率=', score[1], 'loss=', score[0])

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

model.save_weights('./image/photos-model-light.hdf5')
# Out:
# Epoch 1/20
# 6/6 [==============================] - 1s 85ms/step - loss: 1.0774 - accuracy: 0.4084 - val_loss: 0.9971 - val_accuracy: 0.4375
# Epoch 2/20
# 6/6 [==============================] - 0s 63ms/step - loss: 1.0148 - accuracy: 0.4764 - val_loss: 1.0079 - val_accuracy: 0.3958
# Epoch 3/20
# 6/6 [==============================] - 0s 61ms/step - loss: 0.9972 - accuracy: 0.4241 - val_loss: 0.9400 - val_accuracy: 0.5208
# Epoch 4/20
# 6/6 [==============================] - 0s 63ms/step - loss: 0.8988 - accuracy: 0.4974 - val_loss: 1.2109 - val_accuracy: 0.4375
# Epoch 5/20
# 6/6 [==============================] - 0s 62ms/step - loss: 0.9395 - accuracy: 0.4607 - val_loss: 1.0076 - val_accuracy: 0.4583
# Epoch 6/20
# 6/6 [==============================] - 0s 66ms/step - loss: 0.8674 - accuracy: 0.5131 - val_loss: 0.9417 - val_accuracy: 0.4167
# Epoch 7/20
# 6/6 [==============================] - 0s 67ms/step - loss: 0.7853 - accuracy: 0.6073 - val_loss: 0.8126 - val_accuracy: 0.5417
# Epoch 8/20
# 6/6 [==============================] - 0s 67ms/step - loss: 0.7788 - accuracy: 0.6283 - val_loss: 1.2597 - val_accuracy: 0.4375
# Epoch 9/20
# 6/6 [==============================] - 0s 68ms/step - loss: 0.7942 - accuracy: 0.5759 - val_loss: 0.6789 - val_accuracy: 0.7708
# Epoch 10/20
# 6/6 [==============================] - 0s 70ms/step - loss: 0.7040 - accuracy: 0.6911 - val_loss: 0.6702 - val_accuracy: 0.7917
# Epoch 11/20
# 6/6 [==============================] - 0s 70ms/step - loss: 0.5638 - accuracy: 0.7696 - val_loss: 0.5909 - val_accuracy: 0.7292
# Epoch 12/20
# 6/6 [==============================] - 0s 72ms/step - loss: 1.0364 - accuracy: 0.6859 - val_loss: 0.6625 - val_accuracy: 0.7917
# Epoch 13/20
# 6/6 [==============================] - 0s 68ms/step - loss: 0.5142 - accuracy: 0.7958 - val_loss: 0.5009 - val_accuracy: 0.8125
# Epoch 14/20
# 6/6 [==============================] - 0s 69ms/step - loss: 0.7550 - accuracy: 0.6335 - val_loss: 0.5606 - val_accuracy: 0.8333
# Epoch 15/20
# 6/6 [==============================] - 0s 69ms/step - loss: 0.4424 - accuracy: 0.8220 - val_loss: 0.4147 - val_accuracy: 0.8333
# Epoch 16/20
# 6/6 [==============================] - 0s 70ms/step - loss: 0.5202 - accuracy: 0.7487 - val_loss: 0.5720 - val_accuracy: 0.8542
# Epoch 17/20
# 6/6 [==============================] - 0s 70ms/step - loss: 0.4470 - accuracy: 0.8168 - val_loss: 1.1070 - val_accuracy: 0.6250
# Epoch 18/20
# 6/6 [==============================] - 0s 73ms/step - loss: 0.8806 - accuracy: 0.6754 - val_loss: 0.4426 - val_accuracy: 0.8750
# Epoch 19/20
# 6/6 [==============================] - 0s 71ms/step - loss: 0.3684 - accuracy: 0.8586 - val_loss: 0.3484 - val_accuracy: 0.8542
# Epoch 20/20
# 6/6 [==============================] - 0s 73ms/step - loss: 0.3101 - accuracy: 0.8901 - val_loss: 0.3063 - val_accuracy: 0.8542
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3063 - accuracy: 0.8542
# 正解率= 0.8541666865348816 loss= 0.30631688237190247

# %%
# !conda install -c conda-forge cv2

# %%
!
# Out:
# Collecting package metadata (repodata.json): failed
#
# UnavailableInvalidChannel: The channel is not accessible or is invalid.
#   channel name: None
#   channel url: https://api.anaconda.org
#   error code: 404
#
# You will need to adjust your conda configuration to proceed.
# Use `conda config --show channels` to view your configuration's current state,
# and use `conda config --show-sources` to view config file locations.
